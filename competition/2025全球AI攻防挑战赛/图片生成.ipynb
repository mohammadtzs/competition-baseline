# %% [markdown]
# # 2025全球AI攻防挑战赛-赛道一：图片全要素交互认证-生成赛
#
# https://tianchi.aliyun.com/s/90a8875e183258623b8e8cb45967d505
#
# ## 任务说明
#
# 在生成式人工智能（GenAI）蓬勃发展的时代，图像生成技术既展现了令人惊叹的创新能力，也为社会诚信体系带来了前所未有的挑战。从金融、广告等新兴领域，到医疗、政府等传统行业，各类业务场景都依赖于用户提交的图片材料进行身份验证。然而，随着不法分子日益熟练地运用PS、AIGC等工具伪造高仿真图片，真实性鉴别已成为制约行业自动化审核发展的关键瓶颈。
#
# 为此，我们开设“图片全要素场景攻防”专项赛道，在生成阶段，参赛队伍需按照赛事规范生成高度逼真的模拟图片，挑战现有防伪系统的识别极限。我们期待通过这场攻防对抗，推动数字图片真伪鉴别技术的突破性发展，为构建可信的数字社会基础设施贡献力量。
#
# ## 比赛任务
#
# 本赛题分为四个子任务，包括：AIGC图片生成、自然场景图片编辑、视觉文本编辑和Deepfake。参赛者需要尝试使用不同的模型或优化算法，完成所有子任务。各任务具体定义如下：
#
# - **AIGC图片生成**：根据给定的文本提示，生成真实且美观的图片。
# - **自然场景图片编辑**：根据提供的图片和编辑指令，对原图指定区域的内容进行修改。
# - **视觉文本编辑**：根据提供的图片和编辑指令，对原图中的文字信息进行编辑或替换。
# - **Deepfake**：利用给定的人脸图片，对目标图片中的人脸进行替换处理。
#
# 上述任务允许参赛者灵活选择和调整模型或prompt，或通过优化算法提高任务完成的质量，以充分展示技术能力与创新水平。
#
# ## 数据集介绍
#
# 本赛题提供了1000条评测数据，每类任务约250条。评测数据及任务详情记录在 task.csv 文件中，而相关图片保存在 imgs 文件夹内。每张图片均有唯一的标识符（ID），图片名称的格式为 id.jpg。数据集的具体格式如下：
#
# | index |        task_type        | prompt | ori_image | target_image |
# | :---: | :---------------------: | :----: | :-------: | :----------: |
# |   1   |   t2i（AIGC图片生成）   |  xxxx  |           |              |
# |   2   | tie（自然场景图片编辑） |  xxxx  | xxxx.jpg  |              |
# |   3   |  vttie（视觉文本编辑）  |  xxxx  | xxxx.jpg  |              |
# |   4   |        deepfake         |        | xxxx.jpg  |   xxxx.jpg   |
#
# 1. 本赛题提供了1000条评测数据，每类任务约250条。评测数据及任务详情记录在 task.csv 文件中，而相关图片保存在 imgs 文件夹内。每张图片均有唯一的标识符（ID），图片名称的格式为 id.jpg。
# 2. 我们使用了开源数据集来构建本次实验的数据基础。具体而言，从emu_edit_test_set数据集和GEdit-Bench数据集中分别随机抽取了250条样本，用于图像编辑任务和视觉文本编辑任务。此外，为了支持deepfake任务，我们从人脸识别评测集LFW（Labeled Faces in the Wild）中选取了500张不同的人脸图像。所有数据均来源于公开可用的开源数据集，并严格遵守其使用许可协议。
#
# ## 评价指标
#
# 本赛题采用 VIEScore 作为评价指标，该指标由两个子分项组成：SC Score 和 PQ Score。其中，SC Score 用于评估生成内容的一致性，而 PQ Score 用于衡量生成内容的质量和真实性。评分范围为 0~10 分，得分越高表示生成效果越优。
#
# $$
# \text { VIEScore }=\sqrt{\text { sc\_score } * \text { pq\_score }}
# $$
#
#
# 其中deepfake任务使用人脸特征余弦相似度替代原始SC Score。
#
# $$
# \text { VIEScore }=\sqrt{10 * \cos \left(f_{\text {target }}, f_{\text {gen }}\right) * p q \_ \text {score }}
# $$
#
# ## 代码审核
#
# - 参赛者需提交完整的代码，包括数据预处理、特征工程、模型训练和预测等步骤。代码需使用Python编写，并附上详细的注释，以便于评审团进行审核。代码需能够完整地复现参赛者的预测结果。
# - 在比赛结束后，组织者将对入围决赛的参赛者的代码进行审核。代码需满足以下要求：
#   - 代码逻辑清晰，易于理解；
#   - 代码注释充分，方便他人阅读；
#   - 代码运行无报错，能够复现预测结果。
# - 为衡量模型的鲁棒性，排除掉其他滋扰因素。 因此，最终的基准评分受到数据的限制：
#   - 不允许使用测试数据进行手动打标训练。
# - 参赛期间，不得在不同团队之间私下共享代码，任何此类共享比赛代码的行为都将导致取消资格。
#
# ## Baseline
#
# 选手可以使用不同开源模型或生成接口API，例如通义万相、flux、Bagel等。
#
# ## 任务提交说明
#
# 比赛期间，参赛队伍需通过天池平台下载数据，并在本地进行算法调试，随后在线提交结果文件。结果文件需命名为 "参赛队名称_图片生成_result.zip"，其中 ZIP 包需要包含两个内容：result.csv 文件和 imgs 文件夹。ZIP包大小需要限制在2G以内。
#
# - result.csv 文件需以 utf-8-sig 编码格式保存，每一行对应任务生成的结果，包含 "index" 和"gen_image" 两个字段：
#   1. "index" 字段要求与评测集 CSV 的顺序和数量完全一致。
#   2. "gen_image" 字段为生成图片的文件名称，格式需为 "index.jpg"。
# - 所有生成的图片需保存在 imgs 文件夹中，整体与 result.csv 一同打包提交。

# %%
import pandas as pd
import requests
import glob
import time
import cv2
import dlib
import numpy as np
from matplotlib import pyplot as plt
import traceback

# %%
task = pd.read_csv("data/task.csv")
task
# Out:
#      index task_type                                             prompt  \
# 0        1       t2i  一棵令人惊叹的树从太空中的一颗小行星上生长出来，细节复杂，自然光线照射，呈现出超现实的3D渲...
# 1        2       t2i                   宁静的天空中，以概念艺术风格绘制的平和蓬松的云朵，分辨率为4K。
# 2        3       t2i            一张逼真的照片，展示了一位皮肤光滑的男性机器人，它像雕像一样在工厂中摆出姿势。
# 3        4       t2i                这是一幅以平滑的数字肖像插画概念艺术风格描绘的身穿宇航服的年轻宇航员。
# 4        5       t2i  A vibrant cityscape at dawn with sharp focus a...
# ..     ...       ...                                                ...
# 995    996  deepfake                                                NaN
# 996    997  deepfake                                                NaN
# 997    998  deepfake                                                NaN
# 998    999  deepfake                                                NaN
# 999   1000  deepfake                                                NaN
#
#                                 ori_image  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 995  4c234474342546df9034a19dbb230bed.jpg
# 996  0aa8cb980be845a4a30b2248f9abe226.jpg
# 997  a701aec125ce459b9cff76eadd7e0263.jpg
# 998  70eff544233242dab682d2d209fcc2e3.jpg
# 999  4c0b3515b6a14695951fb9d5a3b7f696.jpg
#
#                              target_image
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 995  627b2ac2e0194fc89c015c769decfe6d.jpg
# 996  4d00dbabc9ff47fcba54c21d64bcc458.jpg
# 997  2b8c21b179ec4c1187d60682f7fca808.jpg
# 998  77932521bc3c440eba39c34eafcdee25.jpg
# 999  e8d82077d36d44158a5a582df1287064.jpg
#
# [1000 rows x 5 columns]

# %%
import requests
import os
import time
from urllib.parse import urlparse

def download_image(image_url: str, save_dir: str = "./downloads", filename: str = None) -> str:
    os.makedirs(save_dir, exist_ok=True)
    
    if not filename:
        url_path = urlparse(image_url).path
        filename = os.path.basename(url_path) or "downloaded_image.jpg"
        
        if not os.path.splitext(filename)[1]:
            filename += ".jpg"
    
    response = requests.get(image_url, stream=True)
    response.raise_for_status()  # Raise error for bad status codes
    
    content_type = response.headers.get('content-type', '')
    if 'image/' not in content_type:
        raise ValueError(f"URL does not point to an image (content-type: {content_type})")
    
    file_path = os.path.join(save_dir, filename)
    with open(file_path, 'wb') as f:
        for chunk in response.iter_content(1024):
            f.write(chunk)
    
    return file_path

# %%
# 填入你的key
# https://bailian.console.aliyun.com/?tab=model#/api-key
DASHSCOPE_API_KEY = "sk-6XXX"


def convert_text_prompt_to_image(prompt: str, negative_prompt: str = None):
    """
    https://bailian.console.aliyun.com/?tab=api#/api/?type=model&url=https%3A%2F%2Fhelp.aliyun.com%2Fdocument_detail%2F2862677.html&renderType=iframe
    """
    
    url4generate = "https://dashscope.aliyuncs.com/api/v1/services/aigc/text2image/image-synthesis"
    headers = {
        "X-DashScope-Async": "enable",
        "Authorization": f"Bearer {DASHSCOPE_API_KEY}",
        "Content-Type": "application/json"
    }
    
    data = {
        "model": "wanx2.1-t2i-turbo",
        "input": {
            "prompt": prompt,
        },
        "parameters": {
            "size": "1024*1024",
            "n": 1
        }
    }

    if negative_prompt:
        data["input"]["negative_prompt"] = negative_prompt

    task_id = None
    for _ in range(3):
        try:
            response = requests.post(url4generate, headers=headers, json=data)
            task_id = response.json()["output"]["task_id"]
            break
        except:
            pass

    if not task_id:
        try:
            data["input"]["prompt"] = "穿着黄色衣服的小男孩"
            response = requests.post(url4generate, headers=headers, json=data)
            task_id = response.json()["output"]["task_id"]
        except:
            print(data)
            traceback.print_exc()
            raise Exception
    
    url4result = f"https://dashscope.aliyuncs.com/api/v1/tasks/{task_id}"
    headers = {
        "Authorization": f"Bearer {DASHSCOPE_API_KEY}"
    }
    for _ in range(60):
        try:
            response = requests.get(url4result, headers=headers)
            if response.json()["output"]["task_status"] == "SUCCEEDED":
                return response.json()["output"]["results"][0]["url"]
            else:
               time.sleep(2)
        except:
            pass

    return None

def image_edit_by_prompt(function_str:str, prompt: str, base_image_url:str):
    """
    https://help.aliyun.com/zh/model-studio/wanx-image-edit-api-reference?spm=a2c4g.11186623.help-menu-2400256.d_2_2_2.471812fbpTxg7w&scm=20140722.H_2868981._.OR_help-T_cn~zh-V_1
    """
    url4generate = "https://dashscope.aliyuncs.com/api/v1/services/aigc/image2image/image-synthesis"
    headers = {
        "X-DashScope-Async": "enable",
        "Authorization": f"Bearer {DASHSCOPE_API_KEY}",
        "Content-Type": "application/json"
    }

    data = {
      "model": "wanx2.1-imageedit",
      "input": {
        "function": function_str,
        "prompt": prompt,
        "base_image_url": base_image_url
      },
      "parameters": {
        "n": 1
      }
    }

    try:
        response = requests.post(url4generate, headers=headers, json=data)
        task_id = response.json()["output"]["task_id"]
    except:
        pass

    
    url4result = f"https://dashscope.aliyuncs.com/api/v1/tasks/{task_id}"
    headers = {
        "Authorization": f"Bearer {DASHSCOPE_API_KEY}"
    }
    for _ in range(60):
        try:
            response = requests.get(url4result, headers=headers)
            if response.json()["output"]["task_status"] == "SUCCEEDED":
                return response.json()["output"]["results"][0]["url"]
            else:
               time.sleep(2) 
        except:
            pass

    return None

# %%
detector = dlib.get_frontal_face_detector()
# https://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
predictor = dlib.shape_predictor("./shape_predictor_68_face_landmarks.dat")

def face_swap_using_dlib(source_img_path: str, aim_img_path: str, save_img_path: str):
    face = cv2.imread(source_img_path)
    body = cv2.imread(aim_img_path)

    face_gray = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
    body_gray = cv2.cvtColor(body, cv2.COLOR_BGR2GRAY)
    
    # Create empty matrices in the images' shapes
    height, width = face_gray.shape
    mask = np.zeros((height, width), np.uint8)
    
    height, width, channels = body.shape

    rect = detector(face_gray)[0]
    
    # This creates a with 68 pairs of integer values — these values are the (x, y)-coordinates of the facial structures 
    landmarks = predictor(face_gray, rect)
    landmarks_points = [] 
    
    def get_landmarks(landmarks, landmarks_points):
      for n in range(68):
          x = landmarks.part(n).x
          y = landmarks.part(n).y
          landmarks_points.append((x, y))
    
    get_landmarks(landmarks, landmarks_points)
    
    points = np.array(landmarks_points, np.int32)


    convexhull = cv2.convexHull(points) 
    face_cp = face.copy()
    face_image_1 = cv2.bitwise_and(face, face, mask=mask)


    rect = cv2.boundingRect(convexhull)
    
    subdiv = cv2.Subdiv2D(rect) # Creates an instance of Subdiv2D
    subdiv.insert(landmarks_points) # Insert points into subdiv
    triangles = subdiv.getTriangleList()
    triangles = np.array(triangles, dtype=np.int32)
    
    indexes_triangles = []
    face_cp = face.copy()
    
    def get_index(arr):
        index = 0
        if arr[0]:
            index = arr[0][0]
        return index
    
    for triangle in triangles :
    
        # Gets the vertex of the triangle
        pt1 = (triangle[0], triangle[1])
        pt2 = (triangle[2], triangle[3])
        pt3 = (triangle[4], triangle[5])
        
        # Draws a line for each side of the triangle
        cv2.line(face_cp, pt1, pt2, (255, 255, 255), 3,  0)
        cv2.line(face_cp, pt2, pt3, (255, 255, 255), 3,  0)
        cv2.line(face_cp, pt3, pt1, (255, 255, 255), 3,  0)
    
        index_pt1 = np.where((points == pt1).all(axis=1))
        index_pt1 = get_index(index_pt1)
        index_pt2 = np.where((points == pt2).all(axis=1))
        index_pt2 = get_index(index_pt2)
        index_pt3 = np.where((points == pt3).all(axis=1))
        index_pt3 = get_index(index_pt3)
    
        # Saves coordinates if the triangle exists and has 3 vertices
        if index_pt1 is not None and index_pt2 is not None and index_pt3 is not None:
            vertices = [index_pt1, index_pt2, index_pt3]
            indexes_triangles.append(vertices)

    # Getting landmarks for the face that will have the first one swapped into
    rect2 = detector(body_gray)[0]
    
    # This creates a with 68 pairs of integer values — these values are the (x, y)-coordinates of the facial structures 
    landmarks_2 = predictor(body_gray, rect2)
    landmarks_points2 = []
    
    # Uses the function declared previously to get a list of the landmark coordinates
    get_landmarks(landmarks_2, landmarks_points2)
    
    # Generates a convex hull for the second person
    points2 = np.array(landmarks_points2, np.int32)
    convexhull2 = cv2.convexHull(points2)
    
    body_cp = body.copy()


    lines_space_new_face = np.zeros((height, width, channels), np.uint8)
    body_new_face = np.zeros((height, width, channels), np.uint8)
    
    height, width = face_gray.shape
    lines_space_mask = np.zeros((height, width), np.uint8)
    
    
    for triangle in indexes_triangles:
    
        # Coordinates of the first person's delaunay triangles
        pt1 = landmarks_points[triangle[0]]
        pt2 = landmarks_points[triangle[1]]
        pt3 = landmarks_points[triangle[2]]
    
        # Gets the delaunay triangles
        (x, y, widht, height) = cv2.boundingRect(np.array([pt1, pt2, pt3], np.int32))
        cropped_triangle = face[y: y+height, x: x+widht]
        cropped_mask = np.zeros((height, widht), np.uint8)
    
        # Fills triangle to generate the mask
        points = np.array([[pt1[0]-x, pt1[1]-y], [pt2[0]-x, pt2[1]-y], [pt3[0]-x, pt3[1]-y]], np.int32)
        cv2.fillConvexPoly(cropped_mask, points, 255)
    
        # Draws lines for the triangles
        cv2.line(lines_space_mask, pt1, pt2, 255)
        cv2.line(lines_space_mask, pt2, pt3, 255)
        cv2.line(lines_space_mask, pt1, pt3, 255)
    
        lines_space = cv2.bitwise_and(face, face, mask=lines_space_mask)
    
        # Calculates the delaunay triangles of the second person's face
    
        # Coordinates of the first person's delaunay triangles
        pt1 = landmarks_points2[triangle[0]]
        pt2 = landmarks_points2[triangle[1]]
        pt3 = landmarks_points2[triangle[2]]
    
        # Gets the delaunay triangles
        (x, y, widht, height) = cv2.boundingRect(np.array([pt1, pt2, pt3], np.int32))
        cropped_mask2 = np.zeros((height,widht), np.uint8)
    
        # Fills triangle to generate the mask
        points2 = np.array([[pt1[0]-x, pt1[1]-y], [pt2[0]-x, pt2[1]-y], [pt3[0]-x, pt3[1]-y]], np.int32)
        cv2.fillConvexPoly(cropped_mask2, points2, 255)
    
        # Deforms the triangles to fit the subject's face : https://docs.opencv.org/3.4/d4/d61/tutorial_warp_affine.html
        points =  np.float32(points)
        points2 = np.float32(points2)
        M = cv2.getAffineTransform(points, points2)  # Warps the content of the first triangle to fit in the second one
        dist_triangle = cv2.warpAffine(cropped_triangle, M, (widht, height))
        dist_triangle = cv2.bitwise_and(dist_triangle, dist_triangle, mask=cropped_mask2)
    
        # Joins all the distorted triangles to make the face mask to fit in the second person's features
        body_new_face_rect_area = body_new_face[y: y+height, x: x+widht]
        body_new_face_rect_area_gray = cv2.cvtColor(body_new_face_rect_area, cv2.COLOR_BGR2GRAY)
    
        # Creates a mask
        masked_triangle = cv2.threshold(body_new_face_rect_area_gray, 1, 255, cv2.THRESH_BINARY_INV)
        dist_triangle = cv2.bitwise_and(dist_triangle, dist_triangle, mask=masked_triangle[1])
    
        # Adds the piece to the face mask
        body_new_face_rect_area = cv2.add(body_new_face_rect_area, dist_triangle)
        body_new_face[y: y+height, x: x+widht] = body_new_face_rect_area

    body_face_mask = np.zeros_like(body_gray)
    body_head_mask = cv2.fillConvexPoly(body_face_mask, convexhull2, 255)
    body_face_mask = cv2.bitwise_not(body_head_mask)
    
    body_maskless = cv2.bitwise_and(body, body, mask=body_face_mask)
    result = cv2.add(body_maskless, body_new_face)

    # Gets the center of the face for the body
    (x, y, widht, height) = cv2.boundingRect(convexhull2)
    center_face2 = (int((x+x+widht)/2), int((y+y+height)/2))
    
    seamlessclone = cv2.seamlessClone(result, body, body_head_mask, center_face2, cv2.NORMAL_CLONE)    
    cv2.imwrite(save_img_path, seamlessclone)

# %%
os.makedirs("imgs", exist_ok=True)

# %%
for row in task.iterrows():
    if os.path.exists("imgs/" + str(row[1]['index']) + ".jpg"):
        continue

    url = "http://mirror.coggle.club/tianchi/532389/imgs/01309910e64f48caaffe5b3db8b344e3.jpg"
    download_image(url, "./imgs/", str(row[1]['index']) + ".jpg")

    if row[1].task_type == "t2i":
        url = convert_text_prompt_to_image(row[1].prompt)
        if not url:
            url = "http://mirror.coggle.club/tianchi/532389/imgs/01309910e64f48caaffe5b3db8b344e3.jpg"
        download_image(url, "./imgs/", str(row[1]['index']) + ".jpg")
    
    if row[1].task_type == "tie":
        url = image_edit_by_prompt("stylization_all", row[1].prompt, "http://mirror.coggle.club/tianchi/532389/imgs/" + row[1].ori_image)
        if not url:
            url = "http://mirror.coggle.club/tianchi/532389/imgs/01309910e64f48caaffe5b3db8b344e3.jpg"

        download_image(url, "./imgs/", str(row[1]['index']) + ".jpg")
    
    if row[1].task_type == "vttie":
        url = image_edit_by_prompt("description_edit", row[1].prompt, "http://mirror.coggle.club/tianchi/532389/imgs/" + row[1].ori_image)
        if not url:
            url = "http://mirror.coggle.club/tianchi/532389/imgs/01309910e64f48caaffe5b3db8b344e3.jpg"

        download_image(url, "./imgs/", str(row[1]['index']) + ".jpg")
    
    if row[1].task_type == "deepfake":
        try:
            face_swap_using_dlib(
                "./data/imgs/" + row[1]['ori_image'], 
                "./data/imgs/" + row[1]['target_image'],
                "./imgs/" + str(row[1]['index']) + ".jpg"
            )
        except:
            url = "http://mirror.coggle.club/tianchi/532389/imgs/01309910e64f48caaffe5b3db8b344e3.jpg"
            download_image(url, "./imgs/", str(row[1]['index']) + ".jpg")

# %%
!\rm -rf ./imgs/.ipynb_checkpoints/

# %%
task["gen_image"] = task["index"].astype(str) + ".jpg"

# %%
task[["index", "gen_image"]].to_csv("result.csv", index=None)

# %%
# !zip -r result.zip result.csv imgs/
# Out:
#   adding: result.csv (deflated 63%)
#   adding: imgs/ (stored 0%)
#  (deflated 0%)/63.jpg
#   adding: imgs/823.jpg (deflated 0%)
#   adding: imgs/189.jpg (deflated 0%)
#  (deflated 0%)/77.jpg
#   adding: imgs/837.jpg (deflated 1%)
#   adding: imgs/638.jpg (deflated 0%)
#   adding: imgs/604.jpg (deflated 0%)
#   adding: imgs/162.jpg (deflated 0%)
#  (deflated 0%)/176.jpg
#   adding: imgs/88.jpg (deflated 0%)
#  (deflated 0%)/610.jpg
#   adding: imgs/348.jpg (deflated 0%)
#   adding: imgs/360.jpg (deflated 0%)
#   adding: imgs/406.jpg (deflated 0%)
#   adding: imgs/412.jpg (deflated 0%)
#   adding: imgs/374.jpg (deflated 0%)
#  (deflated 0%)/599.jpg
#   adding: imgs/228.jpg (deflated 0%)
#   adding: imgs/214.jpg (deflated 0%)
#   adding: imgs/572.jpg (deflated 0%)
#  (deflated 0%)/566.jpg
#   adding: imgs/200.jpg (deflated 0%)
#   adding: imgs/957.jpg (deflated 1%)
#   adding: imgs/943.jpg (deflated 1%)
#   adding: imgs/994.jpg (deflated 1%)
#   adding: imgs/758.jpg (deflated 1%)
#   adding: imgs/980.jpg (deflated 0%)
#   adding: imgs/770.jpg (deflated 1%)
#   adding: imgs/764.jpg (deflated 1%)
#   adding: imgs/765.jpg (deflated 1%)
#  (deflated 0%)/771.jpg
#   adding: imgs/981.jpg (deflated 1%)
#   adding: imgs/759.jpg (deflated 1%)
#   adding: imgs/995.jpg (deflated 1%)
#   adding: imgs/942.jpg (deflated 1%)
#   adding: imgs/956.jpg (deflated 1%)
#   adding: imgs/567.jpg (deflated 0%)
#   adding: imgs/201.jpg (deflated 0%)
#   adding: imgs/215.jpg (deflated 0%)
#  (deflated 0%)/573.jpg
#   adding: imgs/229.jpg (deflated 0%)
#   adding: imgs/598.jpg (deflated 0%)
#   adding: imgs/413.jpg (deflated 0%)
#   adding: imgs/375.jpg (deflated 0%)
#  (deflated 0%)/361.jpg
#   adding: imgs/407.jpg (deflated 0%)
#   adding: imgs/349.jpg (deflated 0%)
#   adding: imgs/177.jpg (deflated 0%)
#  (deflated 0%)/611.jpg
#   adding: imgs/89.jpg (deflated 0%)
#   adding: imgs/605.jpg (deflated 0%)
#  (deflated 0%)/163.jpg
#   adding: imgs/639.jpg (deflated 0%)
#  (deflated 0%)/188.jpg
#   adding: imgs/836.jpg (deflated 1%)
#   adding: imgs/76.jpg (deflated 0%)
#   adding: imgs/822.jpg (deflated 1%)
#   adding: imgs/62.jpg (deflated 0%)
#  (deflated 0%)/74.jpg
#   adding: imgs/834.jpg (deflated 1%)
#   adding: imgs/60.jpg (deflated 0%)
#   adding: imgs/820.jpg (deflated 0%)
#  (deflated 0%)/48.jpg
#   adding: imgs/808.jpg (deflated 1%)
#  (deflated 0%)/149.jpg
#   adding: imgs/613.jpg (deflated 0%)
#  (deflated 0%)/175.jpg
#  (deflated 0%)/161.jpg
#   adding: imgs/607.jpg (deflated 0%)
#   adding: imgs/388.jpg (deflated 0%)
#   adding: imgs/439.jpg (deflated 0%)
#  (deflated 0%)/377.jpg
#   adding: imgs/411.jpg (deflated 0%)
#   adding: imgs/405.jpg (deflated 0%)
#   adding: imgs/363.jpg (deflated 0%)
#   adding: imgs/559.jpg (deflated 0%)
#  (deflated 0%)/203.jpg
#   adding: imgs/565.jpg (deflated 0%)
#   adding: imgs/571.jpg (deflated 0%)
#  (deflated 0%)/217.jpg
#   adding: imgs/940.jpg (deflated 1%)
#   adding: imgs/798.jpg (deflated 0%)
#   adding: imgs/954.jpg (deflated 0%)
#   adding: imgs/968.jpg (deflated 1%)
#   adding: imgs/983.jpg (deflated 1%)
#   adding: imgs/997.jpg (deflated 1%)
#   adding: imgs/767.jpg (deflated 1%)
#   adding: imgs/773.jpg (deflated 1%)
#   adding: imgs/772.jpg (deflated 1%)
#   adding: imgs/766.jpg (deflated 1%)
#   adding: imgs/996.jpg (deflated 1%)
#   adding: imgs/982.jpg (deflated 1%)
#   adding: imgs/969.jpg (deflated 0%)
#   adding: imgs/955.jpg (deflated 1%)
#   adding: imgs/799.jpg (deflated 2%)
#   adding: imgs/941.jpg (deflated 1%)
#   adding: imgs/570.jpg (deflated 0%)
#  (deflated 0%)/216.jpg
#   adding: imgs/202.jpg (deflated 0%)
#  (deflated 0%)/564.jpg
#   adding: imgs/558.jpg (deflated 0%)
#   adding: imgs/404.jpg (deflated 0%)
#   adding: imgs/362.jpg (deflated 0%)
#   adding: imgs/376.jpg (deflated 0%)
#   adding: imgs/410.jpg (deflated 0%)
#  (deflated 0%)/438.jpg
#   adding: imgs/389.jpg (deflated 0%)
#   adding: imgs/160.jpg (deflated 0%)
#   adding: imgs/606.jpg (deflated 0%)
#   adding: imgs/612.jpg (deflated 0%)
#  (deflated 0%)/174.jpg
#  (deflated 0%)/148.jpg
#   adding: imgs/809.jpg (deflated 0%)
#   adding: imgs/49.jpg (deflated 0%)
#   adding: imgs/821.jpg (deflated 1%)
#  (deflated 0%)/61.jpg
#   adding: imgs/835.jpg (deflated 1%)
#   adding: imgs/75.jpg (deflated 0%)
#  (deflated 0%)/59.jpg
#   adding: imgs/819.jpg (deflated 1%)
#   adding: imgs/71.jpg (deflated 0%)
#   adding: imgs/831.jpg (deflated 0%)
#  (deflated 0%)/65.jpg
#   adding: imgs/825.jpg (deflated 1%)
#   adding: imgs/170.jpg (deflated 0%)
#  (deflated 0%)/616.jpg
#   adding: imgs/602.jpg (deflated 0%)
#   adding: imgs/164.jpg (deflated 0%)
#  (deflated 0%)/158.jpg
#   adding: imgs/399.jpg (deflated 0%)
#   adding: imgs/414.jpg (deflated 0%)
#   adding: imgs/372.jpg (deflated 0%)
#  (deflated 0%)/366.jpg
#   adding: imgs/400.jpg (deflated 0%)
#   adding: imgs/428.jpg (deflated 0%)
#   adding: imgs/560.jpg (deflated 0%)
#  (deflated 0%)/206.jpg
#   adding: imgs/212.jpg (deflated 0%)
#   adding: imgs/574.jpg (deflated 0%)
#   adding: imgs/548.jpg (deflated 0%)
#   adding: imgs/979.jpg (deflated 2%)
#   adding: imgs/945.jpg (deflated 2%)
#   adding: imgs/951.jpg (deflated 1%)
#   adding: imgs/789.jpg (deflated 1%)
#   adding: imgs/762.jpg (deflated 1%)
#  (deflated 0%)/776.jpg
#   adding: imgs/986.jpg (deflated 1%)
#   adding: imgs/992.jpg (deflated 1%)
#   adding: imgs/993.jpg (deflated 1%)
#   adding: imgs/987.jpg (deflated 2%)
#   adding: imgs/777.jpg (deflated 1%)
#   adding: imgs/763.jpg (deflated 1%)
#   adding: imgs/788.jpg (deflated 1%)
#   adding: imgs/950.jpg (deflated 1%)
#   adding: imgs/944.jpg (deflated 1%)
#   adding: imgs/978.jpg (deflated 1%)
#   adding: imgs/549.jpg (deflated 0%)
#  (deflated 0%)/213.jpg
#   adding: imgs/575.jpg (deflated 0%)
#   adding: imgs/561.jpg (deflated 0%)
#  (deflated 0%)/207.jpg
#   adding: imgs/429.jpg (deflated 0%)
#   adding: imgs/367.jpg (deflated 0%)
#   adding: imgs/401.jpg (deflated 0%)
#   adding: imgs/415.jpg (deflated 0%)
#  (deflated 0%)/373.jpg
#   adding: imgs/398.jpg (deflated 0%)
#   adding: imgs/159.jpg (deflated 0%)
#   adding: imgs/603.jpg (deflated 0%)
#  (deflated 0%)/165.jpg
#   adding: imgs/171.jpg (deflated 0%)
#  (deflated 0%)/617.jpg
#   adding: imgs/824.jpg (deflated 1%)
#   adding: imgs/64.jpg (deflated 0%)
#   adding: imgs/830.jpg (deflated 1%)
#   adding: imgs/70.jpg (deflated 0%)
#   adding: imgs/818.jpg (deflated 1%)
#  (deflated 0%)/58.jpg
#  (deflated 0%)/8.jpg
#   adding: imgs/198.jpg (deflated 0%)
#  (deflated 0%)/66.jpg
#   adding: imgs/826.jpg (deflated 1%)
#   adding: imgs/72.jpg (deflated 0%)
#   adding: imgs/832.jpg (deflated 1%)
#  (deflated 0%)/167.jpg
#   adding: imgs/601.jpg (deflated 0%)
#   adding: imgs/99.jpg (deflated 0%)
#  (deflated 0%)/615.jpg
#   adding: imgs/173.jpg (deflated 0%)
#   adding: imgs/629.jpg (deflated 0%)
#   adding: imgs/403.jpg (deflated 0%)
#   adding: imgs/365.jpg (deflated 0%)
#  (deflated 0%)/371.jpg
#   adding: imgs/417.jpg (deflated 0%)
#   adding: imgs/359.jpg (deflated 0%)
#   adding: imgs/588.jpg (deflated 0%)
#   adding: imgs/577.jpg (deflated 0%)
#  (deflated 0%)/211.jpg
#   adding: imgs/205.jpg (deflated 0%)
#   adding: imgs/563.jpg (deflated 0%)
#  (deflated 0%)/239.jpg
#   adding: imgs/952.jpg (deflated 1%)
#   adding: imgs/946.jpg (deflated 0%)
#   adding: imgs/775.jpg (deflated 2%)
#   adding: imgs/761.jpg (deflated 2%)
#   adding: imgs/749.jpg (deflated 0%)
#   adding: imgs/991.jpg (deflated 0%)
#   adding: imgs/985.jpg (deflated 2%)
#   adding: imgs/984.jpg (deflated 1%)
#   adding: imgs/990.jpg (deflated 1%)
#   adding: imgs/748.jpg (deflated 0%)
#   adding: imgs/760.jpg (deflated 1%)
#   adding: imgs/774.jpg (deflated 1%)
#   adding: imgs/947.jpg (deflated 1%)
#   adding: imgs/953.jpg (deflated 1%)
#  (deflated 0%)/238.jpg
#   adding: imgs/204.jpg (deflated 0%)
#   adding: imgs/562.jpg (deflated 0%)
#  (deflated 0%)/576.jpg
#   adding: imgs/210.jpg (deflated 0%)
#   adding: imgs/589.jpg (deflated 0%)
#  (deflated 0%)/358.jpg
#   adding: imgs/370.jpg (deflated 0%)
#   adding: imgs/416.jpg (deflated 0%)
#   adding: imgs/402.jpg (deflated 0%)
#   adding: imgs/364.jpg (deflated 0%)
#   adding: imgs/628.jpg (deflated 0%)
#   adding: imgs/614.jpg (deflated 0%)
#  (deflated 0%)/172.jpg
#   adding: imgs/166.jpg (deflated 0%)
#  (deflated 0%)/98.jpg
#   adding: imgs/600.jpg (deflated 0%)
#   adding: imgs/833.jpg (deflated 0%)
#  (deflated 0%)/73.jpg
#   adding: imgs/199.jpg (deflated 0%)
#   adding: imgs/827.jpg (deflated 1%)
#   adding: imgs/67.jpg (deflated 0%)
#  (deflated 0%)/9.jpg
#   adding: imgs/698.jpg (deflated 0%)
#   adding: imgs/840.jpg (deflated 1%)
#  (deflated 0%)/14.jpg
#   adding: imgs/854.jpg (deflated 1%)
#   adding: imgs/28.jpg (deflated 0%)
#  (deflated 1%)/868.jpg
#   adding: imgs/883.jpg (deflated 1%)
#   adding: imgs/897.jpg (deflated 0%)
#   adding: imgs/129.jpg (deflated 0%)
#  (deflated 0%)/101.jpg
#   adding: imgs/667.jpg (deflated 0%)
#   adding: imgs/673.jpg (deflated 0%)
#   adding: imgs/115.jpg (deflated 0%)
#  (deflated 0%)/459.jpg
#   adding: imgs/465.jpg (deflated 0%)
#   adding: imgs/303.jpg (deflated 0%)
#   adding: imgs/317.jpg (deflated 0%)
#   adding: imgs/471.jpg (deflated 0%)
#   adding: imgs/288.jpg (deflated 0%)
#  (deflated 0%)/539.jpg
#   adding: imgs/511.jpg (deflated 0%)
#   adding: imgs/277.jpg (deflated 0%)
#   adding: imgs/263.jpg (deflated 0%)
#   adding: imgs/505.jpg (deflated 0%)
#   adding: imgs/934.jpg (deflated 1%)
#   adding: imgs/920.jpg (deflated 1%)
#   adding: imgs/908.jpg (deflated 1%)
#  (deflated 0%)/713.jpg
#   adding: imgs/707.jpg (deflated 0%)
#   adding: imgs/706.jpg (deflated 0%)
#   adding: imgs/712.jpg (deflated 0%)
#   adding: imgs/909.jpg (deflated 1%)
#   adding: imgs/921.jpg (deflated 1%)
#   adding: imgs/935.jpg (deflated 1%)
#   adding: imgs/262.jpg (deflated 0%)
#   adding: imgs/504.jpg (deflated 0%)
#  (deflated 0%)/510.jpg
#   adding: imgs/276.jpg (deflated 0%)
#   adding: imgs/538.jpg (deflated 0%)
#   adding: imgs/289.jpg (deflated 0%)
#   adding: imgs/316.jpg (deflated 0%)
#   adding: imgs/470.jpg (deflated 0%)
#  (deflated 0%)/464.jpg
#   adding: imgs/302.jpg (deflated 0%)
#   adding: imgs/458.jpg (deflated 0%)
#   adding: imgs/672.jpg (deflated 0%)
#  (deflated 0%)/114.jpg
#   adding: imgs/100.jpg (deflated 0%)
#   adding: imgs/666.jpg (deflated 0%)
#   adding: imgs/896.jpg (deflated 1%)
#  (deflated 0%)/128.jpg
#   adding: imgs/882.jpg (deflated 1%)
#   adding: imgs/869.jpg (deflated 0%)
#   adding: imgs/29.jpg (deflated 0%)
#   adding: imgs/855.jpg (deflated 1%)
#  (deflated 0%)/15.jpg
#   adding: imgs/841.jpg (deflated 1%)
#   adding: imgs/699.jpg (deflated 0%)
#   adding: imgs/17.jpg (deflated 0%)
#   adding: imgs/857.jpg (deflated 1%)
#   adding: imgs/843.jpg (deflated 1%)
#  (deflated 1%)/894.jpg
#   adding: imgs/880.jpg (deflated 1%)
#   adding: imgs/658.jpg (deflated 0%)
#   adding: imgs/116.jpg (deflated 0%)
#   adding: imgs/670.jpg (deflated 0%)
#   adding: imgs/664.jpg (deflated 0%)
#  (deflated 0%)/102.jpg
#   adding: imgs/499.jpg (deflated 0%)
#   adding: imgs/328.jpg (deflated 0%)
#   adding: imgs/472.jpg (deflated 0%)
#  (deflated 0%)/314.jpg
#   adding: imgs/300.jpg (deflated 0%)
#   adding: imgs/466.jpg (deflated 0%)
#   adding: imgs/248.jpg (deflated 0%)
#  (deflated 0%)/506.jpg
#   adding: imgs/260.jpg (deflated 0%)
#   adding: imgs/274.jpg (deflated 0%)
#   adding: imgs/512.jpg (deflated 0%)
#   adding: imgs/923.jpg (deflated 1%)
#   adding: imgs/937.jpg (deflated 1%)
#   adding: imgs/738.jpg (deflated 0%)
#   adding: imgs/704.jpg (deflated 0%)
#  (deflated 0%)/710.jpg
#   adding: imgs/711.jpg (deflated 0%)
#   adding: imgs/705.jpg (deflated 0%)
#   adding: imgs/739.jpg (deflated 0%)
#   adding: imgs/936.jpg (deflated 1%)
#   adding: imgs/922.jpg (deflated 1%)
#   adding: imgs/275.jpg (deflated 0%)
#   adding: imgs/513.jpg (deflated 0%)
#  (deflated 0%)/507.jpg
#   adding: imgs/261.jpg (deflated 0%)
#   adding: imgs/249.jpg (deflated 0%)
#   adding: imgs/301.jpg (deflated 0%)
#  (deflated 0%)/467.jpg
#   adding: imgs/473.jpg (deflated 0%)
#   adding: imgs/315.jpg (deflated 0%)
#   adding: imgs/329.jpg (deflated 0%)
#   adding: imgs/498.jpg (deflated 0%)
#   adding: imgs/665.jpg (deflated 0%)
#  (deflated 0%)/103.jpg
#   adding: imgs/117.jpg (deflated 0%)
#  (deflated 0%)/671.jpg
#   adding: imgs/659.jpg (deflated 0%)
#   adding: imgs/881.jpg (deflated 1%)
#   adding: imgs/895.jpg (deflated 2%)
#   adding: imgs/842.jpg (deflated 1%)
#   adding: imgs/856.jpg (deflated 1%)
#   adding: imgs/16.jpg (deflated 0%)
#  (deflated 0%)/12.jpg
#   adding: imgs/852.jpg (deflated 1%)
#   adding: imgs/846.jpg (deflated 1%)
#   adding: imgs/675.jpg (deflated 0%)
#   adding: imgs/113.jpg (deflated 0%)
#  (deflated 0%)/107.jpg
#   adding: imgs/661.jpg (deflated 0%)
#   adding: imgs/891.jpg (deflated 0%)
#   adding: imgs/649.jpg (deflated 0%)
#   adding: imgs/885.jpg (deflated 1%)
#  (deflated 0%)/488.jpg
#   adding: imgs/311.jpg (deflated 0%)
#   adding: imgs/477.jpg (deflated 0%)
#   adding: imgs/463.jpg (deflated 0%)
#   adding: imgs/305.jpg (deflated 0%)
#   adding: imgs/339.jpg (deflated 0%)
#  (deflated 0%)/265.jpg
#   adding: imgs/503.jpg (deflated 0%)
#   adding: imgs/517.jpg (deflated 0%)
#   adding: imgs/271.jpg (deflated 0%)
#   adding: imgs/259.jpg (deflated 0%)
#   adding: imgs/926.jpg (deflated 1%)
#   adding: imgs/932.jpg (deflated 1%)
#   adding: imgs/701.jpg (deflated 0%)
#  (deflated 0%)/715.jpg
#   adding: imgs/729.jpg (deflated 0%)
#   adding: imgs/728.jpg (deflated 0%)
#   adding: imgs/714.jpg (deflated 0%)
#   adding: imgs/700.jpg (deflated 0%)
#   adding: imgs/933.jpg (deflated 2%)
#   adding: imgs/927.jpg (deflated 1%)
#   adding: imgs/258.jpg (deflated 0%)
#  (deflated 0%)/516.jpg
#   adding: imgs/270.jpg (deflated 0%)
#   adding: imgs/264.jpg (deflated 0%)
#   adding: imgs/502.jpg (deflated 0%)
#   adding: imgs/338.jpg (deflated 0%)
#   adding: imgs/462.jpg (deflated 0%)
#  (deflated 0%)/304.jpg
#   adding: imgs/310.jpg (deflated 0%)
#   adding: imgs/476.jpg (deflated 0%)
#   adding: imgs/489.jpg (deflated 0%)
#   adding: imgs/884.jpg (deflated 1%)
#   adding: imgs/648.jpg (deflated 0%)
#   adding: imgs/890.jpg (deflated 1%)
#  (deflated 0%)/106.jpg
#   adding: imgs/660.jpg (deflated 0%)
#   adding: imgs/674.jpg (deflated 0%)
#  (deflated 0%)/112.jpg
#   adding: imgs/847.jpg (deflated 1%)
#   adding: imgs/853.jpg (deflated 1%)
#   adding: imgs/13.jpg (deflated 0%)
#  (deflated 0%)/39.jpg
#   adding: imgs/879.jpg (deflated 1%)
#   adding: imgs/845.jpg (deflated 1%)
#   adding: imgs/689.jpg (deflated 0%)
#   adding: imgs/11.jpg (deflated 0%)
#   adding: imgs/851.jpg (deflated 1%)
#   adding: imgs/662.jpg (deflated 0%)
#  (deflated 0%)/104.jpg
#   adding: imgs/110.jpg (deflated 0%)
#   adding: imgs/676.jpg (deflated 0%)
#  (deflated 2%)/886.jpg
#   adding: imgs/138.jpg (deflated 0%)
#   adding: imgs/892.jpg (deflated 1%)
#   adding: imgs/306.jpg (deflated 0%)
#   adding: imgs/460.jpg (deflated 0%)
#   adding: imgs/474.jpg (deflated 0%)
#  (deflated 0%)/312.jpg
#   adding: imgs/448.jpg (deflated 0%)
#   adding: imgs/299.jpg (deflated 0%)
#   adding: imgs/272.jpg (deflated 0%)
#   adding: imgs/514.jpg (deflated 0%)
#   adding: imgs/500.jpg (deflated 0%)
#  (deflated 0%)/266.jpg
#   adding: imgs/528.jpg (deflated 0%)
#   adding: imgs/919.jpg (deflated 1%)
#   adding: imgs/931.jpg (deflated 1%)
#   adding: imgs/925.jpg (deflated 1%)
#   adding: imgs/716.jpg (deflated 0%)
#   adding: imgs/702.jpg (deflated 0%)
#   adding: imgs/703.jpg (deflated 0%)
#   adding: imgs/717.jpg (deflated 0%)
#  (deflated 0%)/924.jpg
#   adding: imgs/930.jpg (deflated 0%)
#   adding: imgs/918.jpg (deflated 2%)
#   adding: imgs/529.jpg (deflated 0%)
#   adding: imgs/501.jpg (deflated 0%)
#   adding: imgs/267.jpg (deflated 0%)
#   adding: imgs/273.jpg (deflated 0%)
#   adding: imgs/515.jpg (deflated 0%)
#  (deflated 0%)/298.jpg
#   adding: imgs/449.jpg (deflated 0%)
#   adding: imgs/475.jpg (deflated 0%)
#   adding: imgs/313.jpg (deflated 0%)
#   adding: imgs/307.jpg (deflated 0%)
#   adding: imgs/461.jpg (deflated 0%)
#  (deflated 1%)/893.jpg
#   adding: imgs/887.jpg (deflated 0%)
#   adding: imgs/139.jpg (deflated 0%)
#  (deflated 0%)/111.jpg
#   adding: imgs/677.jpg (deflated 0%)
#   adding: imgs/663.jpg (deflated 0%)
#   adding: imgs/105.jpg (deflated 0%)
#  (deflated 1%)/850.jpg
#   adding: imgs/10.jpg (deflated 0%)
#   adding: imgs/688.jpg (deflated 0%)
#   adding: imgs/844.jpg (deflated 1%)
#   adding: imgs/878.jpg (deflated 0%)
#  (deflated 0%)/38.jpg
#   adding: imgs/21.jpg (deflated 0%)
#   adding: imgs/861.jpg (deflated 0%)
#  (deflated 0%)/35.jpg
#   adding: imgs/875.jpg (deflated 2%)
#   adding: imgs/685.jpg (deflated 0%)
#   adding: imgs/691.jpg (deflated 0%)
#   adding: imgs/849.jpg (deflated 1%)
#   adding: imgs/108.jpg (deflated 0%)
#  (deflated 0%)/120.jpg
#   adding: imgs/646.jpg (deflated 0%)
#   adding: imgs/652.jpg (deflated 0%)
#  (deflated 0%)/134.jpg
#   adding: imgs/487.jpg (deflated 0%)
#   adding: imgs/493.jpg (deflated 0%)
#  (deflated 0%)/478.jpg
#   adding: imgs/444.jpg (deflated 0%)
#   adding: imgs/322.jpg (deflated 0%)
#   adding: imgs/336.jpg (deflated 0%)
#   adding: imgs/450.jpg (deflated 0%)
#   adding: imgs/295.jpg (deflated 0%)
#  (deflated 0%)/281.jpg
#   adding: imgs/518.jpg (deflated 0%)
#   adding: imgs/530.jpg (deflated 0%)
#   adding: imgs/256.jpg (deflated 0%)
#  (deflated 0%)/242.jpg
#   adding: imgs/524.jpg (deflated 0%)
#   adding: imgs/915.jpg (deflated 1%)
#   adding: imgs/901.jpg (deflated 1%)
#   adding: imgs/929.jpg (deflated 1%)
#   adding: imgs/732.jpg (deflated 0%)
#   adding: imgs/726.jpg (deflated 0%)
#   adding: imgs/727.jpg (deflated 0%)
#   adding: imgs/733.jpg (deflated 0%)
#   adding: imgs/928.jpg (deflated 1%)
#   adding: imgs/900.jpg (deflated 1%)
#   adding: imgs/914.jpg (deflated 1%)
#  (deflated 0%)/243.jpg
#   adding: imgs/525.jpg (deflated 0%)
#   adding: imgs/531.jpg (deflated 0%)
#   adding: imgs/257.jpg (deflated 0%)
#   adding: imgs/519.jpg (deflated 0%)
#  (deflated 0%)/280.jpg
#   adding: imgs/294.jpg (deflated 0%)
#   adding: imgs/337.jpg (deflated 0%)
#   adding: imgs/451.jpg (deflated 0%)
#   adding: imgs/445.jpg (deflated 0%)
#   adding: imgs/323.jpg (deflated 0%)
#  (deflated 0%)/479.jpg
#   adding: imgs/492.jpg (deflated 0%)
#   adding: imgs/486.jpg (deflated 0%)
#   adding: imgs/653.jpg (deflated 0%)
#   adding: imgs/135.jpg (deflated 0%)
#  (deflated 0%)/121.jpg
#   adding: imgs/647.jpg (deflated 0%)
#  (deflated 0%)/109.jpg
#   adding: imgs/848.jpg (deflated 1%)
#   adding: imgs/690.jpg (deflated 0%)
#   adding: imgs/684.jpg (deflated 0%)
#   adding: imgs/874.jpg (deflated 1%)
#  (deflated 0%)/34.jpg
#   adding: imgs/860.jpg (deflated 1%)
#   adding: imgs/20.jpg (deflated 0%)
#  (deflated 0%)/36.jpg
#   adding: imgs/876.jpg (deflated 1%)
#   adding: imgs/22.jpg (deflated 0%)
#   adding: imgs/862.jpg (deflated 0%)
#   adding: imgs/692.jpg (deflated 0%)
#   adding: imgs/686.jpg (deflated 0%)
#  (deflated 0%)/679.jpg
#   adding: imgs/137.jpg (deflated 0%)
#   adding: imgs/889.jpg (deflated 1%)
#   adding: imgs/651.jpg (deflated 0%)
#  (deflated 0%)/645.jpg
#   adding: imgs/123.jpg (deflated 0%)
#   adding: imgs/490.jpg (deflated 0%)
#   adding: imgs/484.jpg (deflated 0%)
#  (deflated 0%)/309.jpg
#   adding: imgs/453.jpg (deflated 0%)
#   adding: imgs/335.jpg (deflated 0%)
#   adding: imgs/321.jpg (deflated 0%)
#   adding: imgs/447.jpg (deflated 0%)
#   adding: imgs/282.jpg (deflated 0%)
#  (deflated 0%)/296.jpg
#   adding: imgs/269.jpg (deflated 0%)
#   adding: imgs/527.jpg (deflated 0%)
#   adding: imgs/241.jpg (deflated 0%)
#   adding: imgs/255.jpg (deflated 4%)
#  (deflated 0%)/533.jpg
#   adding: imgs/902.jpg (deflated 1%)
#   adding: imgs/916.jpg (deflated 1%)
#   adding: imgs/719.jpg (deflated 0%)
#   adding: imgs/725.jpg (deflated 0%)
#   adding: imgs/731.jpg (deflated 0%)
#   adding: imgs/730.jpg (deflated 0%)
#   adding: imgs/724.jpg (deflated 0%)
#  (deflated 0%)/718.jpg
#   adding: imgs/917.jpg (deflated 1%)
#   adding: imgs/903.jpg (deflated 1%)
#   adding: imgs/254.jpg (deflated 0%)
#   adding: imgs/532.jpg (deflated 0%)
#   adding: imgs/526.jpg (deflated 0%)
#  (deflated 0%)/240.jpg
#   adding: imgs/268.jpg (deflated 0%)
#   adding: imgs/297.jpg (deflated 0%)
#   adding: imgs/283.jpg (deflated 0%)
#   adding: imgs/320.jpg (deflated 0%)
#   adding: imgs/446.jpg (deflated 0%)
#  (deflated 0%)/452.jpg
#   adding: imgs/334.jpg (deflated 0%)
#   adding: imgs/308.jpg (deflated 0%)
#   adding: imgs/485.jpg (deflated 0%)
#   adding: imgs/491.jpg (deflated 0%)
#   adding: imgs/644.jpg (deflated 0%)
#  (deflated 0%)/122.jpg
#   adding: imgs/136.jpg (deflated 0%)
#   adding: imgs/650.jpg (deflated 0%)
#  (deflated 0%)/888.jpg
#   adding: imgs/678.jpg (deflated 0%)
#   adding: imgs/687.jpg (deflated 0%)
#   adding: imgs/693.jpg (deflated 0%)
#   adding: imgs/863.jpg (deflated 1%)
#  (deflated 0%)/23.jpg
#   adding: imgs/877.jpg (deflated 1%)
#   adding: imgs/37.jpg (deflated 0%)
#  (deflated 0%)/697.jpg
#   adding: imgs/683.jpg (deflated 0%)
#   adding: imgs/33.jpg (deflated 0%)
#   adding: imgs/873.jpg (deflated 1%)
#  (deflated 0%)/27.jpg
#   adding: imgs/867.jpg (deflated 1%)
#   adding: imgs/654.jpg (deflated 0%)
#  (deflated 0%)/132.jpg
#   adding: imgs/126.jpg (deflated 0%)
#   adding: imgs/898.jpg (deflated 1%)
#   adding: imgs/640.jpg (deflated 0%)
#   adding: imgs/668.jpg (deflated 0%)
#   adding: imgs/495.jpg (deflated 0%)
#   adding: imgs/481.jpg (deflated 0%)
#  (deflated 0%)/330.jpg
#   adding: imgs/456.jpg (deflated 0%)
#   adding: imgs/442.jpg (deflated 0%)
#   adding: imgs/324.jpg (deflated 0%)
#   adding: imgs/318.jpg (deflated 0%)
#   adding: imgs/287.jpg (deflated 0%)
#  (deflated 0%)/293.jpg
#   adding: imgs/244.jpg (deflated 0%)
#   adding: imgs/522.jpg (deflated 0%)
#   adding: imgs/536.jpg (deflated 0%)
#  (deflated 0%)/250.jpg
#   adding: imgs/278.jpg (deflated 0%)
#   adding: imgs/907.jpg (deflated 1%)
#   adding: imgs/913.jpg (deflated 1%)
#   adding: imgs/720.jpg (deflated 0%)
#   adding: imgs/734.jpg (deflated 0%)
#  (deflated 0%)/708.jpg
#   adding: imgs/709.jpg (deflated 0%)
#   adding: imgs/735.jpg (deflated 0%)
#   adding: imgs/721.jpg (deflated 0%)
#   adding: imgs/912.jpg (deflated 1%)
#   adding: imgs/906.jpg (deflated 1%)
#   adding: imgs/279.jpg (deflated 0%)
#   adding: imgs/537.jpg (deflated 0%)
#  (deflated 0%)/251.jpg
#   adding: imgs/245.jpg (deflated 0%)
#  (deflated 0%)/523.jpg
#   adding: imgs/292.jpg (deflated 0%)
#   adding: imgs/286.jpg (deflated 0%)
#   adding: imgs/319.jpg (deflated 0%)
#   adding: imgs/443.jpg (deflated 0%)
#   adding: imgs/325.jpg (deflated 0%)
#  (deflated 0%)/331.jpg
#   adding: imgs/457.jpg (deflated 0%)
#   adding: imgs/480.jpg (deflated 0%)
#   adding: imgs/494.jpg (deflated 0%)
#   adding: imgs/669.jpg (deflated 0%)
#  (deflated 0%)/127.jpg
#   adding: imgs/641.jpg (deflated 0%)
#   adding: imgs/899.jpg (deflated 0%)
#   adding: imgs/655.jpg (deflated 0%)
#   adding: imgs/133.jpg (deflated 0%)
#  (deflated 3%)/866.jpg
#   adding: imgs/26.jpg (deflated 0%)
#   adding: imgs/872.jpg (deflated 1%)
#  (deflated 0%)/32.jpg
#   adding: imgs/682.jpg (deflated 0%)
#   adding: imgs/696.jpg (deflated 0%)
#   adding: imgs/680.jpg (deflated 0%)
#   adding: imgs/18.jpg (deflated 0%)
#  (deflated 1%)/858.jpg
#   adding: imgs/694.jpg (deflated 0%)
#   adding: imgs/24.jpg (deflated 0%)
#   adding: imgs/864.jpg (deflated 1%)
#   adding: imgs/30.jpg (deflated 0%)
#  (deflated 0%)/870.jpg
#   adding: imgs/643.jpg (deflated 0%)
#   adding: imgs/125.jpg (deflated 0%)
#  (deflated 0%)/131.jpg
#   adding: imgs/657.jpg (deflated 0%)
#   adding: imgs/119.jpg (deflated 0%)
#   adding: imgs/482.jpg (deflated 0%)
#  (deflated 0%)/496.jpg
#   adding: imgs/327.jpg (deflated 0%)
#   adding: imgs/441.jpg (deflated 0%)
#   adding: imgs/455.jpg (deflated 0%)
#   adding: imgs/333.jpg (deflated 0%)
#  (deflated 0%)/469.jpg
#   adding: imgs/290.jpg (deflated 0%)
#   adding: imgs/284.jpg (deflated 0%)
#   adding: imgs/253.jpg (deflated 0%)
#   adding: imgs/535.jpg (deflated 0%)
#   adding: imgs/521.jpg (deflated 0%)
#  (deflated 0%)/247.jpg
#   adding: imgs/509.jpg (deflated 0%)
#   adding: imgs/938.jpg (deflated 1%)
#   adding: imgs/910.jpg (deflated 0%)
#   adding: imgs/904.jpg (deflated 1%)
#   adding: imgs/737.jpg (deflated 0%)
#  (deflated 0%)/723.jpg
#   adding: imgs/722.jpg (deflated 0%)
#   adding: imgs/736.jpg (deflated 0%)
#   adding: imgs/905.jpg (deflated 1%)
#   adding: imgs/911.jpg (deflated 1%)
#   adding: imgs/939.jpg (deflated 0%)
#   adding: imgs/508.jpg (deflated 0%)
#  (deflated 0%)/520.jpg
#   adding: imgs/246.jpg (deflated 1%)
#   adding: imgs/252.jpg (deflated 0%)
#   adding: imgs/534.jpg (deflated 0%)
#   adding: imgs/285.jpg (deflated 0%)
#  (deflated 0%)/291.jpg
#   adding: imgs/468.jpg (deflated 0%)
#   adding: imgs/454.jpg (deflated 0%)
#   adding: imgs/332.jpg (deflated 0%)
#   adding: imgs/326.jpg (deflated 0%)
#   adding: imgs/440.jpg (deflated 0%)
#  (deflated 0%)/497.jpg
#   adding: imgs/483.jpg (deflated 0%)
#   adding: imgs/118.jpg (deflated 0%)
#  (deflated 0%)/130.jpg
#   adding: imgs/656.jpg (deflated 0%)
#   adding: imgs/642.jpg (deflated 0%)
#   adding: imgs/124.jpg (deflated 0%)
#   adding: imgs/871.jpg (deflated 1%)
#  (deflated 0%)/31.jpg
#   adding: imgs/865.jpg (deflated 0%)
#  (deflated 0%)/25.jpg
#  (deflated 0%)/695.jpg
#   adding: imgs/859.jpg (deflated 1%)
#   adding: imgs/19.jpg (deflated 0%)
#   adding: imgs/681.jpg (deflated 0%)
#  (deflated 0%)/42.jpg
#   adding: imgs/802.jpg (deflated 1%)
#   adding: imgs/4.jpg (deflated 0%)
#  (deflated 0%)/56.jpg
#   adding: imgs/816.jpg (deflated 0%)
#   adding: imgs/180.jpg (deflated 0%)
#   adding: imgs/194.jpg (deflated 0%)
#  (deflated 0%)/81.jpg
#   adding: imgs/619.jpg (deflated 0%)
#   adding: imgs/95.jpg (deflated 0%)
#   adding: imgs/625.jpg (deflated 0%)
#  (deflated 0%)/143.jpg
#   adding: imgs/157.jpg (deflated 0%)
#   adding: imgs/631.jpg (deflated 0%)
#  (deflated 0%)/382.jpg
#   adding: imgs/396.jpg (deflated 0%)
#   adding: imgs/369.jpg (deflated 0%)
#   adding: imgs/341.jpg (deflated 0%)
#   adding: imgs/427.jpg (deflated 0%)
#   adding: imgs/433.jpg (deflated 0%)
#  (deflated 0%)/355.jpg
#   adding: imgs/590.jpg (deflated 0%)
#   adding: imgs/584.jpg (deflated 0%)
#   adding: imgs/209.jpg (deflated 0%)
#  (deflated 0%)/235.jpg
#   adding: imgs/553.jpg (deflated 0%)
#   adding: imgs/547.jpg (deflated 0%)
#  (deflated 0%)/221.jpg
#   adding: imgs/976.jpg (deflated 1%)
#   adding: imgs/962.jpg (deflated 1%)
#   adding: imgs/792.jpg (deflated 1%)
#   adding: imgs/786.jpg (deflated 1%)
#   adding: imgs/779.jpg (deflated 1%)
#   adding: imgs/751.jpg (deflated 1%)
#   adding: imgs/989.jpg (deflated 1%)
#   adding: imgs/745.jpg (deflated 0%)
#   adding: imgs/744.jpg (deflated 0%)
#   adding: imgs/988.jpg (deflated 1%)
#   adding: imgs/750.jpg (deflated 0%)
#   adding: imgs/778.jpg (deflated 1%)
#   adding: imgs/787.jpg (deflated 1%)
#   adding: imgs/793.jpg (deflated 1%)
#   adding: imgs/963.jpg (deflated 1%)
#   adding: imgs/977.jpg (deflated 1%)
#   adding: imgs/546.jpg (deflated 0%)
#  (deflated 0%)/220.jpg
#   adding: imgs/234.jpg (deflated 0%)
#   adding: imgs/552.jpg (deflated 0%)
#  (deflated 0%)/208.jpg
#   adding: imgs/585.jpg (deflated 0%)
#   adding: imgs/591.jpg (deflated 0%)
#   adding: imgs/432.jpg (deflated 0%)
#   adding: imgs/354.jpg (deflated 0%)
#  (deflated 0%)/340.jpg
#   adding: imgs/426.jpg (deflated 0%)
#   adding: imgs/368.jpg (deflated 0%)
#   adding: imgs/397.jpg (deflated 0%)
#   adding: imgs/383.jpg (deflated 0%)
#  (deflated 0%)/156.jpg
#   adding: imgs/630.jpg (deflated 0%)
#   adding: imgs/624.jpg (deflated 0%)
#  (deflated 0%)/142.jpg
#   adding: imgs/94.jpg (deflated 0%)
#   adding: imgs/618.jpg (deflated 0%)
#  (deflated 0%)/80.jpg
#   adding: imgs/195.jpg (deflated 0%)
#  (deflated 0%)/181.jpg
#   adding: imgs/5.jpg (deflated 0%)
#   adding: imgs/817.jpg (deflated 1%)
#  (deflated 0%)/57.jpg
#   adding: imgs/803.jpg (deflated 0%)
#   adding: imgs/43.jpg (deflated 0%)
#  (deflated 0%)/55.jpg
#   adding: imgs/815.jpg (deflated 2%)
#   adding: imgs/7.jpg (deflated 0%)
#  (deflated 0%)/41.jpg
#   adding: imgs/801.jpg (deflated 1%)
#   adding: imgs/69.jpg (deflated 0%)
#   adding: imgs/829.jpg (deflated 1%)
#   adding: imgs/197.jpg (deflated 0%)
#  (deflated 0%)/183.jpg
#   adding: imgs/96.jpg (deflated 0%)
#  (deflated 0%)/168.jpg
#   adding: imgs/82.jpg (deflated 0%)
#   adding: imgs/632.jpg (deflated 0%)
#  (deflated 0%)/154.jpg
#   adding: imgs/140.jpg (deflated 0%)
#   adding: imgs/626.jpg (deflated 0%)
#   adding: imgs/395.jpg (deflated 0%)
#  (deflated 0%)/381.jpg
#   adding: imgs/418.jpg (deflated 0%)
#   adding: imgs/356.jpg (deflated 0%)
#   adding: imgs/430.jpg (deflated 0%)
#   adding: imgs/424.jpg (deflated 0%)
#  (deflated 0%)/342.jpg
#   adding: imgs/587.jpg (deflated 0%)
#   adding: imgs/593.jpg (deflated 0%)
#   adding: imgs/578.jpg (deflated 0%)
#  (deflated 0%)/222.jpg
#   adding: imgs/544.jpg (deflated 0%)
#   adding: imgs/550.jpg (deflated 0%)
#  (deflated 0%)/236.jpg
#   adding: imgs/961.jpg (deflated 2%)
#   adding: imgs/975.jpg (deflated 1%)
#   adding: imgs/785.jpg (deflated 1%)
#   adding: imgs/949.jpg (deflated 1%)
#   adding: imgs/791.jpg (deflated 1%)
#   adding: imgs/746.jpg (deflated 0%)
#   adding: imgs/752.jpg (deflated 1%)
#   adding: imgs/753.jpg (deflated 1%)
#   adding: imgs/747.jpg (deflated 0%)
#   adding: imgs/790.jpg (deflated 1%)
#   adding: imgs/948.jpg (deflated 1%)
#   adding: imgs/784.jpg (deflated 1%)
#   adding: imgs/974.jpg (deflated 0%)
#   adding: imgs/960.jpg (deflated 1%)
#   adding: imgs/551.jpg (deflated 0%)
#  (deflated 0%)/237.jpg
#   adding: imgs/223.jpg (deflated 0%)
#  (deflated 0%)/545.jpg
#   adding: imgs/579.jpg (deflated 0%)
#   adding: imgs/592.jpg (deflated 0%)
#   adding: imgs/586.jpg (deflated 0%)
#   adding: imgs/425.jpg (deflated 0%)
#   adding: imgs/343.jpg (deflated 0%)
#  (deflated 0%)/357.jpg
#   adding: imgs/431.jpg (deflated 0%)
#   adding: imgs/419.jpg (deflated 0%)
#   adding: imgs/380.jpg (deflated 0%)
#   adding: imgs/394.jpg (deflated 0%)
#  (deflated 0%)/141.jpg
#   adding: imgs/627.jpg (deflated 0%)
#   adding: imgs/633.jpg (deflated 0%)
#  (deflated 0%)/155.jpg
#   adding: imgs/83.jpg (deflated 0%)
#   adding: imgs/97.jpg (deflated 0%)
#  (deflated 0%)/169.jpg
#   adding: imgs/182.jpg (deflated 0%)
#   adding: imgs/828.jpg (deflated 1%)
#  (deflated 0%)/68.jpg
#   adding: imgs/196.jpg (deflated 0%)
#   adding: imgs/800.jpg (deflated 1%)
#  (deflated 0%)/40.jpg
#   adding: imgs/814.jpg (deflated 1%)
#   adding: imgs/54.jpg (deflated 0%)
#  (deflated 0%)/6.jpg
#   adding: imgs/192.jpg (deflated 0%)
#  (deflated 0%)/78.jpg
#   adding: imgs/838.jpg (deflated 0%)
#   adding: imgs/186.jpg (deflated 0%)
#  (deflated 0%)/2.jpg
#   adding: imgs/50.jpg (deflated 0%)
#   adding: imgs/810.jpg (deflated 1%)
#  (deflated 0%)/44.jpg
#   adding: imgs/804.jpg (deflated 1%)
#   adding: imgs/151.jpg (deflated 0%)
#   adding: imgs/637.jpg (deflated 0%)
#   adding: imgs/623.jpg (deflated 0%)
#  (deflated 0%)/145.jpg
#  (deflated 0%)/93.jpg
#   adding: imgs/87.jpg (deflated 0%)
#  (deflated 0%)/179.jpg
#   adding: imgs/390.jpg (deflated 0%)
#   adding: imgs/384.jpg (deflated 0%)
#   adding: imgs/435.jpg (deflated 0%)
#   adding: imgs/353.jpg (deflated 0%)
#   adding: imgs/347.jpg (deflated 0%)
#  (deflated 0%)/421.jpg
#   adding: imgs/409.jpg (deflated 0%)
#   adding: imgs/582.jpg (deflated 0%)
#   adding: imgs/596.jpg (deflated 0%)
#   adding: imgs/541.jpg (deflated 0%)
#  (deflated 0%)/227.jpg
#   adding: imgs/233.jpg (deflated 0%)
#   adding: imgs/555.jpg (deflated 0%)
#  (deflated 0%)/569.jpg
#   adding: imgs/958.jpg (deflated 1%)
#   adding: imgs/780.jpg (deflated 1%)
#   adding: imgs/794.jpg (deflated 1%)
#   adding: imgs/964.jpg (deflated 1%)
#   adding: imgs/970.jpg (deflated 1%)
#   adding: imgs/743.jpg (deflated 0%)
#   adding: imgs/757.jpg (deflated 1%)
#   adding: imgs/756.jpg (deflated 0%)
#   adding: imgs/742.jpg (deflated 0%)
#   adding: imgs/971.jpg (deflated 1%)
#   adding: imgs/965.jpg (deflated 1%)
#   adding: imgs/795.jpg (deflated 1%)
#   adding: imgs/781.jpg (deflated 0%)
#   adding: imgs/959.jpg (deflated 1%)
#  (deflated 0%)/568.jpg
#   adding: imgs/232.jpg (deflated 0%)
#   adding: imgs/554.jpg (deflated 0%)
#   adding: imgs/540.jpg (deflated 0%)
#  (deflated 0%)/226.jpg
#   adding: imgs/597.jpg (deflated 0%)
#   adding: imgs/583.jpg (deflated 0%)
#   adding: imgs/408.jpg (deflated 0%)
#   adding: imgs/346.jpg (deflated 0%)
#   adding: imgs/420.jpg (deflated 0%)
#  (deflated 0%)/434.jpg
#   adding: imgs/352.jpg (deflated 0%)
#   adding: imgs/385.jpg (deflated 0%)
#   adding: imgs/391.jpg (deflated 0%)
#  (deflated 0%)/86.jpg
#   adding: imgs/178.jpg (deflated 0%)
#   adding: imgs/92.jpg (deflated 0%)
#  (deflated 0%)/622.jpg
#   adding: imgs/144.jpg (deflated 0%)
#  (deflated 0%)/150.jpg
#   adding: imgs/636.jpg (deflated 0%)
#   adding: imgs/805.jpg (deflated 1%)
#   adding: imgs/45.jpg (deflated 0%)
#  (deflated 0%)/3.jpg
#   adding: imgs/811.jpg (deflated 1%)
#   adding: imgs/51.jpg (deflated 0%)
#   adding: imgs/839.jpg (deflated 1%)
#  (deflated 0%)/79.jpg
#   adding: imgs/187.jpg (deflated 0%)
#  (deflated 0%)/193.jpg
#   adding: imgs/185.jpg (deflated 0%)
#  (deflated 0%)/191.jpg
#   adding: imgs/47.jpg (deflated 0%)
#   adding: imgs/807.jpg (deflated 0%)
#  (deflated 0%)/53.jpg
#   adding: imgs/813.jpg (deflated 1%)
#   adding: imgs/1.jpg (deflated 0%)
#  (deflated 0%)/146.jpg
#   adding: imgs/620.jpg (deflated 0%)
#   adding: imgs/634.jpg (deflated 0%)
#  (deflated 0%)/152.jpg
#   adding: imgs/84.jpg (deflated 0%)
#  (deflated 0%)/608.jpg
#   adding: imgs/90.jpg (deflated 0%)
#   adding: imgs/387.jpg (deflated 0%)
#   adding: imgs/393.jpg (deflated 0%)
#  (deflated 0%)/422.jpg
#   adding: imgs/344.jpg (deflated 0%)
#   adding: imgs/350.jpg (deflated 0%)
#   adding: imgs/436.jpg (deflated 0%)
#   adding: imgs/378.jpg (deflated 0%)
#   adding: imgs/595.jpg (deflated 0%)
#   adding: imgs/581.jpg (deflated 0%)
#  (deflated 0%)/556.jpg
#   adding: imgs/230.jpg (deflated 0%)
#  (deflated 0%)/224.jpg
#   adding: imgs/542.jpg (deflated 0%)
#   adding: imgs/218.jpg (deflated 0%)
#   adding: imgs/797.jpg (deflated 1%)
#   adding: imgs/783.jpg (deflated 1%)
#   adding: imgs/973.jpg (deflated 1%)
#   adding: imgs/967.jpg (deflated 1%)
#   adding: imgs/754.jpg (deflated 1%)
#  (deflated 0%)/740.jpg
#   adding: imgs/998.jpg (deflated 2%)
#   adding: imgs/768.jpg (deflated 1%)
#   adding: imgs/769.jpg (deflated 1%)
#   adding: imgs/999.jpg (deflated 1%)
#   adding: imgs/741.jpg (deflated 0%)
#   adding: imgs/755.jpg (deflated 0%)
#   adding: imgs/966.jpg (deflated 1%)
#   adding: imgs/972.jpg (deflated 1%)
#   adding: imgs/782.jpg (deflated 1%)
#   adding: imgs/796.jpg (deflated 1%)
#   adding: imgs/219.jpg (deflated 0%)
#  (deflated 0%)/225.jpg
#   adding: imgs/543.jpg (deflated 0%)
#   adding: imgs/557.jpg (deflated 0%)
#   adding: imgs/231.jpg (deflated 0%)
#  (deflated 0%)/580.jpg
#   adding: imgs/594.jpg (deflated 0%)
#   adding: imgs/1000.jpg (deflated 1%)
#   adding: imgs/379.jpg (deflated 0%)
#   adding: imgs/351.jpg (deflated 0%)
#   adding: imgs/437.jpg (deflated 0%)
#   adding: imgs/423.jpg (deflated 0%)
#  (deflated 0%)/345.jpg
#   adding: imgs/392.jpg (deflated 0%)
#  (deflated 0%)/386.jpg
#  (deflated 0%)/91.jpg
#   adding: imgs/609.jpg (deflated 0%)
#   adding: imgs/85.jpg (deflated 0%)
#   adding: imgs/635.jpg (deflated 0%)
#  (deflated 0%)/153.jpg
#   adding: imgs/147.jpg (deflated 0%)
#  (deflated 0%)/621.jpg
#   adding: imgs/812.jpg (deflated 1%)
#   adding: imgs/52.jpg (deflated 0%)
#   adding: imgs/806.jpg (deflated 0%)
#  (deflated 0%)/46.jpg
#   adding: imgs/190.jpg (deflated 0%)
#  (deflated 0%)/184.jpg

# %%
# !ls imgs/ | wc -l
# Out:
#     1000
